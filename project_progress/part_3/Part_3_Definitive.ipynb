# %%
import math
import os
import re
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from numpy.linalg import norm
from pathlib import Path
from gensim.models import Word2Vec
from sentence_transformers import SentenceTransformer
# !pip install -q sentence-transformers

# %%
# ------------------ Load & Preprocess ------------------
# 1) Define base directory
#BASE = Path(r"C:\\Users\\Ramona\\.vscode\\IR_Project\\IRWA_Final_Project").resolve()
BASE = Path(".").resolve() 
 
# 2) Define files directly
PROCESSED_DATA_FILE = BASE / r"data\processed\products_clean.parquet"
LABELS_FILE         = BASE / r"data\raw\validation_labels.csv"
INDEX_FILE          = BASE / r"data\index\inverted_index.json"
# 3) Define queries
ALL_QUERIES = [
    {'query_id': 1, 'query': "women full sleeve sweatshirt cotton"},
    {'query_id': 2, 'query': "men slim jeans blue"},
    {'query_id': 3, 'query': "long sleeve denim jacket blue"},
    {'query_id': 4, 'query': "cotton shirt man regular fit"},
    {'query_id': 5, 'query': "women western wear cotton"},
    {'query_id': 6, 'query': "machine wash suitabl woman"},
    {'query_id': 7, 'query': "brand blend fabric shirt"},
]

# 3) Sanity checks
print("processed:", PROCESSED_DATA_FILE.exists(), PROCESSED_DATA_FILE)
print("labels   :", LABELS_FILE.exists(), LABELS_FILE)
os.makedirs(INDEX_FILE.parent, exist_ok=True)

# 4) Load data 
try:
    df = pd.read_parquet(PROCESSED_DATA_FILE)
except Exception as e:
    print("pandas read_parquet failed:", e)
    import pyarrow.dataset as ds
    df_ = ds.dataset(PROCESSED_DATA_FILE, format="parquet").to_table().to_pandas()

def tokenize(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    return text.split()

df["tokens"] = df["title_tokens"].apply(tokenize)
df["len"] = df["tokens"].apply(len)

# Stats for BM25
N = len(df)
df_counts = Counter(t for tokens in df["tokens"] for t in set(tokens))
avgdl = df["len"].mean()
# Out:
# processed: True C:\Users\david\IRWA_Definitivo\IRWA_Final_Project\project_progress\part_3\data\processed\products_clean.parquet
# labels   : True C:\Users\david\IRWA_Definitivo\IRWA_Final_Project\project_progress\part_3\data\raw\validation_labels.csv

# %%
#--------------------WORD2VEC REPREESENTATIONS----------------
# 1) Prepare training corpus (list of token lists)
corpus_tokens = df["tokens"].tolist()
pids = df["pid"].tolist()

# 2) Train Word2Vec model
w2v_model = Word2Vec(
    sentences=corpus_tokens,
    vector_size=100,  
    window=5,
    min_count=2,
    workers=4,
    sg=1               
)

# 3) Function to average word vectors
def average_vector(tokens, model):
    vectors = []
    for t in tokens:
        if t in model.wv:
            vectors.append(model.wv[t])
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# 4) Build document vectors for ALL documents
doc_vectors = {}

for pid, tokens in zip(pids, corpus_tokens):
    doc_vectors[pid] = average_vector(tokens, w2v_model)

# 5) Cosine similarity for dense vectors
def cosine_sim(a, b):
    if norm(a) == 0 or norm(b) == 0:
        return 0
    return np.dot(a, b) / (norm(a) * norm(b))

# 6) Word2Vec ranking function
def word2vec_rank(query):
    q_tokens = tokenize(query)
    q_vec = average_vector(q_tokens, w2v_model)

    scores = []
    for pid, d_vec in doc_vectors.items():
        sim = cosine_sim(q_vec, d_vec)
        scores.append((pid, sim))

    scores_sorted = sorted(scores, key=lambda x: x[1], reverse=True)
    return scores_sorted[:20]

# %%
# ------------------ IDF for TF-IDF ------------------
def idf(term):
    return math.log((N + 1) / (df_counts.get(term, 0) + 1)) + 1

# Build TF-IDF vectors per document (normalized)
tfidf_vecs = {}
for _, row in df.iterrows():
    doc_id = row["pid"]
    c = Counter(row["tokens"])
    vec = {t: c[t] * idf(t) for t in c}
    norm_val = math.sqrt(sum(v*v for v in vec.values()))
    if norm_val > 0:
        vec = {k: v/norm_val for k, v in vec.items()}
    tfidf_vecs[doc_id] = vec

# Cosine for sparse TF-IDF
def cosine(qvec, dvec):
    return sum(qvec[t] * dvec.get(t, 0) for t in qvec)

# %%
# ------------------ BM25 ------------------
k1, b = 1.5, 0.75

def bm25(query_terms, doc_id):
    score = 0.0
    dl = df.loc[df["pid"] == doc_id, "len"].iloc[0]
    for term in query_terms:
        f = tfidf_vecs[doc_id].get(term, 0)
        if f == 0: continue
        df_t = df_counts.get(term, 0)
        idf_bm = math.log((N - df_t + 0.5) / (df_t + 0.5) + 1e-9)
        denom = f + k1 * (1 - b + b * dl / avgdl)
        score += idf_bm * f * (k1 + 1) / (denom + 1e-9)
    return score

# %%
def custom_score(query_terms, doc_id):
    # ---------- Textual Relevance ----------
    # TF-IDF cosine similarity
    c = Counter(query_terms)
    qvec = {t: c[t]*idf(t) for t in c}
    norm = math.sqrt(sum(v*v for v in qvec.values()))
    if norm > 0:
        qvec = {k: v/norm for k, v in qvec.items()}
    tfidf_score = cosine(qvec, tfidf_vecs[doc_id])

    # Title boost: more weight if query terms are in the title
    title_tokens = df.loc[df["pid"] == doc_id, "tokens"].iloc[0]
    title_boost = sum(1 for t in query_terms if t in title_tokens)

    # ---------- Numerical / Product Features ----------
    row = df.loc[df["pid"] == doc_id].iloc[0]

    # Price: lower price = higher score (normalize)
    price = row["selling_price"] if not pd.isna(row["selling_price"]) else 0
    price_score = 1 / (1 + price/1000)  # scale down very expensive products

    # Customer rating: higher rating = higher score
    rating = row["average_rating"] if not pd.isna(row["average_rating"]) else 0
    rating_score = rating / 5  # normalize to [0,1]

    # Brand popularity: simple proxy using number of products from this brand
    brand = row["brand"]
    brand_count = len(df[df["brand"] == brand])
    brand_score = min(brand_count / 50, 1)  # cap to 1 to avoid huge influence

    # ---------- Combine Scores ----------
    final_score = (tfidf_score
                   + 0.5*title_boost          # title boost
                   + 0.3*price_score          # weight for price
                   + 0.3*rating_score         # weight for rating
                   + 0.2*brand_score)         # weight for brand popularity

    return final_score

# %%
# Load labels for evaluation only
df_labels = pd.read_csv(LABELS_FILE)

# %%
def rank_query(query_id):
    # Get query text from ALL_QUERIES
    query = next(q["query"] for q in ALL_QUERIES if q["query_id"] == query_id)
    q_terms = tokenize(query)

    # Build normalized TF-IDF query vector
    qc = Counter(q_terms)
    qvec = {t: qc[t]*idf(t) for t in qc}
    norm = math.sqrt(sum(v*v for v in qvec.values()))
    if norm > 0:
        qvec = {k: v/norm for k, v in qvec.items()}

    # Score only documents under the same query_id
    subset = df_labels[df_labels["query_id"] == query_id]

    tfidf_scores, bm25_scores, custom_scores = [], [], []

    for _, row in subset.iterrows():
        doc_id = row["pid"]

        tfidf_scores.append((doc_id, cosine(qvec, tfidf_vecs[doc_id])))
        bm25_scores.append((doc_id, bm25(q_terms, doc_id)))
        custom_scores.append((doc_id, custom_score(q_terms, doc_id)))

    return {
        "TF-IDF": sorted(tfidf_scores, key=lambda x: x[1], reverse=True),
        "BM25": sorted(bm25_scores, key=lambda x: x[1], reverse=True),
        "Custom": sorted(custom_scores, key=lambda x: x[1], reverse=True),
    }

# %%
def print_top_results(results, df, top_n=10):
    """
    results: list of (pid, score)
    df: main dataframe with product metadata
    """
    cols_to_show = [
        "pid",
        "title_raw",
        "brand",
        "category",
        "sub_category",
        "selling_price",
        "average_rating"
    ]
    
    top = results[:top_n]
    pids = [pid for pid, score in top]

    merged = df[df["pid"].isin(pids)][cols_to_show].copy()

    # Add score column to output
    score_map = dict(top)
    merged["score"] = merged["pid"].map(score_map)

    # Sort by score descending
    merged = merged.sort_values("score", ascending=False)

    print(merged.to_string(index=False))

# %%
# Run ranking
results_dict = rank_query(2)  # Query ID

print("\n=== TF-IDF Top 10 ===")
print_top_results(results_dict["TF-IDF"], df, top_n=10)

print("\n=== BM25 Top 10 ===")
print_top_results(results_dict["BM25"], df, top_n=10)

print("\n=== Custom Top 10 ===")
print_top_results(results_dict["Custom"], df, top_n=10)
# Out:
# === TF-IDF Top 10 ===
#              pid                title_raw         brand                 category sub_category  selling_price  average_rating    score
# JEAFTGSGTYKZGAEZ      Slim Men Blue Jeans           lev clothing and accessories   bottomwear         3679.0             NaN 0.280758
# JEAFSKYHRVZSABPR      Slim Men Blue Jeans      ecko unl clothing and accessories   bottomwear          974.0             3.3 0.280758
# JEAFHEZH9KVGTJJS      Slim Men Blue Jeans u.s. polo ass clothing and accessories   bottomwear         1979.0             4.3 0.280758
# JEAEKZFJHSKJMV58    Slim Women Blue Jeans           wab clothing and accessories   bottomwear         1656.0             4.3 0.241368
# JEAF8CHSVCP5GUH9    Slim Women Blue Jeans             g clothing and accessories   bottomwear         5990.0             4.3 0.241368
# JEAFS2JWKPBRNYTU    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1499.0             3.1 0.241368
# JEAFS2JG6N7ZTFYS    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1399.0             3.2 0.241368
# JEAFWZXE6KYHBZRU    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 0.241368
# JEAFWG4GK2HGF7AF    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 0.241368
# JEAFVXG4GGZH9VFA Slim Men Dark Blue Jeans         timeo clothing and accessories   bottomwear          995.0             NaN 0.238428
#
# === BM25 Top 10 ===
#              pid                title_raw         brand                 category sub_category  selling_price  average_rating    score
# JEAFTGSGTYKZGAEZ      Slim Men Blue Jeans           lev clothing and accessories   bottomwear         3679.0             NaN 2.994174
# JEAFSKYHRVZSABPR      Slim Men Blue Jeans      ecko unl clothing and accessories   bottomwear          974.0             3.3 2.994174
# JEAFHEZH9KVGTJJS      Slim Men Blue Jeans u.s. polo ass clothing and accessories   bottomwear         1979.0             4.3 2.994174
# JEAEKZFJHSKJMV58    Slim Women Blue Jeans           wab clothing and accessories   bottomwear         1656.0             4.3 2.923197
# JEAF8CHSVCP5GUH9    Slim Women Blue Jeans             g clothing and accessories   bottomwear         5990.0             4.3 2.923197
# JEAFS2JWKPBRNYTU    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1499.0             3.1 2.923197
# JEAFS2JG6N7ZTFYS    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1399.0             3.2 2.923197
# JEAFWZXE6KYHBZRU    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 2.923197
# JEAFWG4GK2HGF7AF    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 2.923197
# JEAFVXG4GGZH9VFA Slim Men Dark Blue Jeans         timeo clothing and accessories   bottomwear          995.0             NaN 2.372541
#
# === Custom Top 10 ===
#              pid                title_raw         brand                 category sub_category  selling_price  average_rating    score
# JEAFHEZH9KVGTJJS      Slim Men Blue Jeans u.s. polo ass clothing and accessories   bottomwear         1979.0             4.3 2.339462
# JEAFSKYHRVZSABPR      Slim Men Blue Jeans      ecko unl clothing and accessories   bottomwear          974.0             3.3 2.330733
# JEAE32FSQ4JXYJK6 Slim Men Dark Blue Jeans           wab clothing and accessories   bottomwear         1499.0             3.0 2.238476
# JEAFTGSGTYKZGAEZ      Slim Men Blue Jeans           lev clothing and accessories   bottomwear         3679.0             NaN 2.044874
# JEAFVXG4GGZH9VFA Slim Men Dark Blue Jeans         timeo clothing and accessories   bottomwear          995.0             NaN 1.936804
# JEAEKZFJHSKJMV58    Slim Women Blue Jeans           wab clothing and accessories   bottomwear         1656.0             4.3 1.812320
# JEAFS2JG6N7ZTFYS    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1399.0             3.2 1.758420
# JEAFS2JWKPBRNYTU    Slim Women Blue Jeans        cantab clothing and accessories   bottomwear         1499.0             3.1 1.747416
# JEAFWZXE6KYHBZRU    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 1.745443
# JEAFWG4GK2HGF7AF    Slim Women Blue Jeans   fuel clothi clothing and accessories   bottomwear          999.0             3.9 1.745443

# %%
# -------------WORD2VEC RESULTS FOR PART 2 QUERIES----------------

for q in ALL_QUERIES:
    print(f"\nWord2Vec Results for: {q['query']}")
    print("=" * 80)

    results = word2vec_rank(q["query"])

    print(f"{'PID':<20} {'SCORE':<10} TITLE")
    print("-" * 80)

    for pid, score in results[:10]:  # Top-10
        title = df.loc[df["pid"] == pid, "title_raw"].iloc[0]
        print(f"{pid:<20} {float(score):<10.4f} {title}")
# Out:
# Word2Vec Results for: women full sleeve sweatshirt cotton
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# SWSFM8JWXH5ZMHHZ     0.9131     Full Sleeve Embroidered Men Sweatshirt
# SWSFM8JWBHHSHZBH     0.9131     Full Sleeve Embroidered Men Sweatshirt
# SWSFXMFPVYZ2YGGQ     0.9131     Full Sleeve Embroidered Men Sweatshirt
# SWSFGNK2VZBAM7GG     0.9131     Full Sleeve Embroidered Men Sweatshirt
# SWSFVEV2JMCVXTRQ     0.9131     Full Sleeve Embroidered Men Sweatshirt
# SWSFVEV2RGM3NDRS     0.9131     Full Sleeve Embroidered Men Sweatshirt
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# TRKFSZQUG3QEEZVG     0.8790     Rico Classic Organic Cotton Men Trunks
# SCFFV7UZHG8CYHMZ     0.8614     Lucky Bird Printed Pure Cotton Women Scarf
# SWLFZC9HWDNYAUDP     0.8601     K J TRADERS Cotton Solid Women, Women Shawl  (Beige)
# BRFFSMJKJTWQHZFF     0.8474     Men Rico Classic Organic Cotton Brief
# TROFNVM4GTQT3GKY     0.8332     Women Cream Cotton Silk Trousers
# TROFNVDFQUMHAH9Y     0.8292     Men Blue Cotton Silk Trousers
# KTAFMRFCBV8VMD64     0.8226     Women Solid Pure Cotton High Low Kurta  (White)
# TROFNVDVFHNXEKUG     0.8207     Women Beige Cotton Silk Trousers
# TROFNVM4ZCFWHTHH     0.8203     Men Beige Cotton Silk Trousers
# HARFXZDHKVUZFEPZ     0.8202     Printed Cotton Men Harem Pants
#
# Word2Vec Results for: machine wash suitabl woman
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# BZRFZS22AGUMBBNA     0.9190     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Black)
# BZRFZR4FJTHHFNMZ     0.9129     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Light Blue)
# BZRFZR58UUHSWN73     0.9093     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Maroon)
# BZRFVEMMJEHHUD4H     0.9015     Checkered Single Breasted Casual Women Blazer  (Purple)
# BZRFZQ9JQHGHEQSK     0.8911     Solid Single Breasted Casual Women Blazer  (Blue)
# BZRFZ6HYZHEFYTHK     0.8793     Solid Single Breasted Casual Men Blazer  (Dark Blue)
# BZRFZQ9JWEEHK8FH     0.8639     Solid Mandarin Casual Women Blazer  (Green)
# SHTFW5YQKZGNWSEB     0.8627     Women Regular Fit Washed Button Down Collar Casual Shirt
# SHTFW5F2MZVM8AYT     0.8624     Men Regular Fit Washed Button Down Collar Casual Shirt
# BZRFVDHX3AVFHCHC     0.8621     Self Design Single Breasted Casual Men Blazer  (Grey)
#
# Word2Vec Results for: brand blend fabric shirt
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# FABFZH85MZ8S52FH     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8ZQAFJU7AW     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8HGKDW2MZK     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH7ZKYZEAH6T     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8Q9UJHHHGZ     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8SHA4ZPGNU     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZHGYFDTXRKMY     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8AGS4WTKPW     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH92SREJWEV2     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8KCK8E2KH3     0.9613     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)

# %%
sent2vec_model = SentenceTransformer("all-MiniLM-L6-v2")  

# 1) Build sentence embeddings for ALL product titles
print("Computing document embeddings...")
doc_sent_embeddings = {}
titles = df["title_raw"].tolist()
pids = df["pid"].tolist()

emb_matrix = sent2vec_model.encode(titles, show_progress_bar=True)

for pid, emb in zip(pids, emb_matrix):
    doc_sent_embeddings[pid] = emb


# 2) Sentence2Vec ranking function
def sentence2vec_rank(query, top_k=20):
    q_emb = sent2vec_model.encode([query])[0]
    
    scores = []
    for pid, d_emb in doc_sent_embeddings.items():
        s = np.dot(q_emb, d_emb) / (norm(q_emb) * norm(d_emb))
        scores.append((pid, float(s)))
    
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    return scores[:top_k]


# 3) Result Printing
def print_sentence2vec_results(query, top_n=10):
    print(f"\nSentence2Vec Results for: {query}")
    print("=" * 80)
    print(f"{'PID':<20} {'SCORE':<10} TITLE")
    print("-" * 80)

    for pid, score in sentence2vec_rank(query, top_n):
        title = df.loc[df["pid"] == pid, "title_raw"].iloc[0]
        print(f"{pid:<20} {score:<10.4f} {title}")


# 4) Run for all queries (same as Word2Vec)
for q in ALL_QUERIES:
    print_sentence2vec_results(q["query"], top_n=10)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\david\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\david\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Computing document embeddings...
# Batches:   0%|          | 0/878 [00:00<?, ?it/s]
# Sentence2Vec Results for: women full sleeve sweatshirt cotton
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# SWSFVEV2VZBMYW7U     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSF9W3ZHHJFQFJF     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFHHR4B7QNFBRR     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFM8JWZX8GQA5X     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFYFFYHHDFZBRM     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFYFFFJZN6P6ZW     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFYFFYNUHYEQGD     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFXZWT8GF6MNGU     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFYFFYQ7Z3ZKN6     0.8632     Full Sleeve Printed Women Sweatshirt
# SWSFYFFFFYZ896TJ     0.8632     Full Sleeve Printed Women Sweatshirt
#
# Sentence2Vec Results for: men slim jeans blue
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# JEAFPMKZGHS2ZTKG     0.9453     Slim Men Light Blue Jeans
# JEAF8S4GGRU9VY46     0.9453     Slim Men Light Blue Jeans
# JEAFEC2GEMGBWHA5     0.9453     Slim Men Light Blue Jeans
# JEAFVXHKTSH3GXUG     0.9453     Slim Men Light Blue Jeans
# JEAEHGRJSGGYEYYX     0.9453     Slim Men Light Blue Jeans
# JEAENP3UUGESZVH9     0.9453     Slim Men Light Blue Jeans
# JEAFF87GFTNXY4CH     0.9453     Slim Men Light Blue Jeans
# JEAEKMCHWJJVUPQE     0.9382     Slim Men Blue Jeans
# JEAEKZFGQSYRFV9K     0.9382     Slim Men Blue Jeans
# JEAERYGSGHGM9JBA     0.9382     Slim Men Blue Jeans
#
# Sentence2Vec Results for: long sleeve denim jacket blue
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# JCKFSHEZUYMTUDH7     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFWC5ZAF3BRTPA     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFWC5ZHSAEVYMS     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFURYWGYKVKFH3     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFWC5YPXZG6S7F     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFVDPW4WNPBGS2     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFYY97BC7KWPM4     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFWC5YZKFWXGEB     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFXNVMP5XZZNHA     0.7478     Full Sleeve Solid Men Denim Jacket
# JCKFXNVMC435YMSU     0.7478     Full Sleeve Solid Men Denim Jacket
#
# Sentence2Vec Results for: cotton shirt man regular fit
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
