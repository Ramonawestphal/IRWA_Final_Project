# %%
import math
import os
import re
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from numpy.linalg import norm
from pathlib import Path
from gensim.models import Word2Vec

# %%
# ------------------ Load & Preprocess ------------------
# 1) Define base directory
#BASE = Path(r"C:\\Users\\Ramona\\.vscode\\IR_Project\\IRWA_Final_Project").resolve()
BASE = Path(".").resolve() 
 
# 2) Define files directly
PROCESSED_DATA_FILE = BASE / r"data\processed\products_clean.parquet"
LABELS_FILE         = BASE / r"data\raw\validation_labels.csv"
INDEX_FILE          = BASE / r"data\index\inverted_index.json"
# 3) Define queries
ALL_QUERIES = [
    {'query_id': 1, 'query': "women full sleeve sweatshirt cotton"},
    {'query_id': 2, 'query': "men slim jeans blue"},
    {'query_id': 3, 'query': "long sleeve denim jacket blue"},
    {'query_id': 4, 'query': "cotton shirt man regular fit"},
    {'query_id': 5, 'query': "women western wear cotton"},
    {'query_id': 6, 'query': "machine wash suitabl woman"},
    {'query_id': 7, 'query': "brand blend fabric shirt"},
]

# 3) Sanity checks
print("processed:", PROCESSED_DATA_FILE.exists(), PROCESSED_DATA_FILE)
print("labels   :", LABELS_FILE.exists(), LABELS_FILE)
os.makedirs(INDEX_FILE.parent, exist_ok=True)

# 4) Load data 
try:
    df = pd.read_parquet(PROCESSED_DATA_FILE)
except Exception as e:
    print("pandas read_parquet failed:", e)
    import pyarrow.dataset as ds
    df_ = ds.dataset(PROCESSED_DATA_FILE, format="parquet").to_table().to_pandas()

def tokenize(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    return text.split()

df["tokens"] = df["title_tokens"].apply(tokenize)
df["len"] = df["tokens"].apply(len)

# Stats for BM25
N = len(df)
df_counts = Counter(t for tokens in df["tokens"] for t in set(tokens))
avgdl = df["len"].mean()
# Out:
# processed: True C:\Users\david\IRWA_Definitivo\IRWA_Final_Project\project_progress\part_3\data\processed\products_clean.parquet
# labels   : True C:\Users\david\IRWA_Definitivo\IRWA_Final_Project\project_progress\part_3\data\raw\validation_labels.csv

# %%
#--------------------WORD2VEC REPREESENTATIONS----------------
# 1) Prepare training corpus (list of token lists)
corpus_tokens = df["tokens"].tolist()
pids = df["pid"].tolist()

# 2) Train Word2Vec model
w2v_model = Word2Vec(
    sentences=corpus_tokens,
    vector_size=100,  
    window=5,
    min_count=2,
    workers=4,
    sg=1               
)

# 3) Function to average word vectors
def average_vector(tokens, model):
    vectors = []
    for t in tokens:
        if t in model.wv:
            vectors.append(model.wv[t])
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# 4) Build document vectors for ALL documents
doc_vectors = {}

for pid, tokens in zip(pids, corpus_tokens):
    doc_vectors[pid] = average_vector(tokens, w2v_model)

# 5) Cosine similarity for dense vectors
def cosine_sim(a, b):
    if norm(a) == 0 or norm(b) == 0:
        return 0
    return np.dot(a, b) / (norm(a) * norm(b))

# 6) Word2Vec ranking function
def word2vec_rank(query):
    q_tokens = tokenize(query)
    q_vec = average_vector(q_tokens, w2v_model)

    scores = []
    for pid, d_vec in doc_vectors.items():
        sim = cosine_sim(q_vec, d_vec)
        scores.append((pid, sim))

    scores_sorted = sorted(scores, key=lambda x: x[1], reverse=True)
    return scores_sorted[:20]

# %%
# ------------------ IDF for TF-IDF ------------------
def idf(term):
    return math.log((N + 1) / (df_counts.get(term, 0) + 1)) + 1

# Build TF-IDF vectors per document (normalized)
tfidf_vecs = {}
for _, row in df.iterrows():
    doc_id = row["pid"]
    c = Counter(row["tokens"])
    vec = {t: c[t] * idf(t) for t in c}
    norm_val = math.sqrt(sum(v*v for v in vec.values()))
    if norm_val > 0:
        vec = {k: v/norm_val for k, v in vec.items()}
    tfidf_vecs[doc_id] = vec

# Cosine for sparse TF-IDF
def cosine(qvec, dvec):
    return sum(qvec[t] * dvec.get(t, 0) for t in qvec)

# %%
# ------------------ BM25 ------------------
k1, b = 1.5, 0.75

def bm25(query_terms, doc_id):
    score = 0.0
    dl = df.loc[df["pid"] == doc_id, "len"].iloc[0]
    for term in query_terms:
        f = tfidf_vecs[doc_id].get(term, 0)
        if f == 0: continue
        df_t = df_counts.get(term, 0)
        idf_bm = math.log((N - df_t + 0.5) / (df_t + 0.5) + 1e-9)
        denom = f + k1 * (1 - b + b * dl / avgdl)
        score += idf_bm * f * (k1 + 1) / (denom + 1e-9)
    return score

# %%
def custom_score(query_terms, doc_id):
    # ---------- Textual Relevance ----------
    # TF-IDF cosine similarity
    c = Counter(query_terms)
    qvec = {t: c[t]*idf(t) for t in c}
    norm = math.sqrt(sum(v*v for v in qvec.values()))
    if norm > 0:
        qvec = {k: v/norm for k, v in qvec.items()}
    tfidf_score = cosine(qvec, tfidf_vecs[doc_id])

    # Title boost: more weight if query terms are in the title
    title_tokens = df.loc[df["pid"] == doc_id, "tokens"].iloc[0]
    title_boost = sum(1 for t in query_terms if t in title_tokens)

    # ---------- Numerical / Product Features ----------
    row = df.loc[df["pid"] == doc_id].iloc[0]

    # Price: lower price = higher score (normalize)
    price = row["selling_price"] if not pd.isna(row["selling_price"]) else 0
    price_score = 1 / (1 + price/1000)  # scale down very expensive products

    # Customer rating: higher rating = higher score
    rating = row["average_rating"] if not pd.isna(row["average_rating"]) else 0
    rating_score = rating / 5  # normalize to [0,1]

    # Brand popularity: simple proxy using number of products from this brand
    brand = row["brand"]
    brand_count = len(df[df["brand"] == brand])
    brand_score = min(brand_count / 50, 1)  # cap to 1 to avoid huge influence

    # ---------- Combine Scores ----------
    final_score = (tfidf_score
                   + 0.5*title_boost          # title boost
                   + 0.3*price_score          # weight for price
                   + 0.3*rating_score         # weight for rating
                   + 0.2*brand_score)         # weight for brand popularity

    return final_score

# %%
# Load labels for evaluation only
df_labels = pd.read_csv(LABELS_FILE)

# %%
def rank_query(query_id):
    # Get query text from ALL_QUERIES
    query = next(q["query"] for q in ALL_QUERIES if q["query_id"] == query_id)
    q_terms = tokenize(query)

    # Build normalized TF-IDF query vector
    qc = Counter(q_terms)
    qvec = {t: qc[t]*idf(t) for t in qc}
    norm = math.sqrt(sum(v*v for v in qvec.values()))
    if norm > 0:
        qvec = {k: v/norm for k, v in qvec.items()}

    # Score only documents under the same query_id
    subset = df_labels[df_labels["query_id"] == query_id]

    tfidf_scores, bm25_scores, custom_scores = [], [], []

    for _, row in subset.iterrows():
        doc_id = row["pid"]

        tfidf_scores.append((doc_id, cosine(qvec, tfidf_vecs[doc_id])))
        bm25_scores.append((doc_id, bm25(q_terms, doc_id)))
        custom_scores.append((doc_id, custom_score(q_terms, doc_id)))

    return {
        "TF-IDF": sorted(tfidf_scores, key=lambda x: x[1], reverse=True),
        "BM25": sorted(bm25_scores, key=lambda x: x[1], reverse=True),
        "Custom": sorted(custom_scores, key=lambda x: x[1], reverse=True),
    }

# %%
def print_top_results(results, df, top_n=10):
    """
    results: list of (pid, score)
    df: main dataframe with product metadata
    """
    cols_to_show = [
        "pid",
        "title_raw",
        "brand",
        "category",
        "sub_category",
        "selling_price",
        "average_rating"
    ]
    
    top = results[:top_n]
    pids = [pid for pid, score in top]

    merged = df[df["pid"].isin(pids)][cols_to_show].copy()

    # Add score column to output
    score_map = dict(top)
    merged["score"] = merged["pid"].map(score_map)

    # Sort by score descending
    merged = merged.sort_values("score", ascending=False)

    print(merged.to_string(index=False))

# %%
# -------------WORD2VEC RESULTS FOR PART 2 QUERIES----------------

for q in ALL_QUERIES:
    print(f"\nWord2Vec Results for: {q['query']}")
    print("=" * 80)

    results = word2vec_rank(q["query"])

    print(f"{'PID':<20} {'SCORE':<10} TITLE")
    print("-" * 80)

    for pid, score in results[:10]:  # Top-10
        title = df.loc[df["pid"] == pid, "title_raw"].iloc[0]
        print(f"{pid:<20} {float(score):<10.4f} {title}")
# Out:
# Word2Vec Results for: women full sleeve sweatshirt cotton
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# SWSF8922F2GZNBKH     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF9W4GEANZJH6Y     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF8922HHDGB7CH     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF8922KZTGQHT2     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF8925HDFHAHBX     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF8922HYCYKXP6     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF9ZBTHZNCVM4R     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSF9W7QAKGVV7UH     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSFMG3GSBPYHTFT     0.9092     Full Sleeve Striped Men Sweatshirt
# SWSFJY5ZJZKVGUFT     0.9091     Full Sleeve Striped Women Sweatshirt
#
# Word2Vec Results for: men slim jeans blue
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# JEAEKMCHWJJVUPQE     0.9337     Slim Men Blue Jeans
# JEAEKZFGQSYRFV9K     0.9337     Slim Men Blue Jeans
# JEAERYGSGHGM9JBA     0.9337     Slim Men Blue Jeans
# JEAEKSFSX6ZFX3ES     0.9337     Slim Men Blue Jeans
# JEAERYJ25KBEYNTG     0.9337     Slim Men Blue Jeans
# JEAEQ5FUQSUZHVYA     0.9337     Slim Men Blue Jeans
# JEAFPMKZDSAGG7EX     0.9337     Slim Men Blue Jeans
# JEAEKH6EJAZBY2FX     0.9337     Slim Men Blue Jeans
# JEAEKSCH3EXCGUEF     0.9337     Slim Men Blue Jeans
# JEAEHYGF7JRHVYV4     0.9337     Slim Men Blue Jeans
#
# Word2Vec Results for: long sleeve denim jacket blue
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# RUGFM6GPAANF4HWP     0.8799     Men Jacket Style Full Sleeve Dark Blue Shrug
# RUGFM6GPZXZ8C3NF     0.8799     Men Jacket Style Full Sleeve Dark Blue Shrug
# RUGFX854ZPPTXHVH     0.8799     Men Jacket Style Full Sleeve Dark Blue Shrug
# RUGFX854KA5E5PQJ     0.8712     Men Jacket Style Full Sleeve Dark Green Shrug
# RUGFM8CYPGBKMHUH     0.8532     Women Jacket Style Full Sleeve Grey Shrug
# RUGFM8CYUJ6G4VHN     0.8525     Women Jacket Style Full Sleeve Black Shrug
# JCKFNNHS4MZHTHHH     0.8461     Sleeveless Textured Women Jacket
# JCKFNNHSBFDFB46R     0.8461     Sleeveless Textured Women Jacket
# JCKFNNHSWFZFPSVY     0.8451     Sleeveless Textured Men Jacket
# JCKFNNHSDNFNCAUF     0.8451     Sleeveless Textured Men Jacket
#
# Word2Vec Results for: cotton shirt man regular fit
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# TROFY2YDSF86AUSB     0.9381     Regular Fit Men White Cotton Blend Trousers
# TROFY2YF45HJWGCN     0.9381     Regular Fit Men White Cotton Blend Trousers
# TROFS6WBGWZ9RETW     0.9381     Regular Fit Men White Cotton Blend Trousers
# TROEATNWHJKYH9ZT     0.9381     Regular Fit Men White Cotton Blend Trousers
# TROFYFX6XK4HYZFN     0.9364     Slim Fit Men White Cotton Blend Trousers
# TROEZDQHUKQUXQUR     0.9364     Slim Fit Men White Cotton Blend Trousers
# TROFWBY5DCA4NKHY     0.9364     Slim Fit Men White Cotton Blend Trousers
# TROFTVVFXZJ9YJWZ     0.9361     Slim Fit Women Red Cotton Blend Trousers
# TROFY2YFSMNNGQXJ     0.9355     Regular Fit Women White Cotton Blend Trousers
# TROFZ3S2U9FH9KZZ     0.9355     Regular Fit Women White Cotton Blend Trousers
#
# Word2Vec Results for: women western wear cotton
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# TRKFSZQUG3QEEZVG     0.8823     Rico Classic Organic Cotton Men Trunks
# BRFFSMJKJTWQHZFF     0.8538     Men Rico Classic Organic Cotton Brief
# SWLFZC9HWDNYAUDP     0.8519     K J TRADERS Cotton Solid Women, Women Shawl  (Beige)
# SCFFV7UZHG8CYHMZ     0.8506     Lucky Bird Printed Pure Cotton Women Scarf
# KTAFMRFCBV8VMD64     0.8296     Women Solid Pure Cotton High Low Kurta  (White)
# KTAFV92XXUFHFKJP     0.8292     Women Solid Khadi Cotton Ethnic Dress  (Purple)
# KTAFV92XN8VJK8AY     0.8292     Women Solid Khadi Cotton Ethnic Dress  (Purple)
# KTAFV92XV9YSJ4FY     0.8269     Men Solid Khadi Cotton Ethnic Dress  (Purple)
# KTAFV92XGCTAZFNE     0.8221     Women Solid Khadi Cotton Ethnic Dress  (Blue)
# KTAFV92XXBWFRG6R     0.8195     Men Solid Khadi Cotton Ethnic Dress  (Green)
#
# Word2Vec Results for: machine wash suitabl woman
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# BZRFZS22AGUMBBNA     0.9115     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Black)
# BZRFZR4FJTHHFNMZ     0.9033     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Light Blue)
# BZRFZR58UUHSWN73     0.9000     Solid Single Breasted Wedding, Casual, Party, Formal, Festive & Wedding Women Blazer  (Maroon)
# BZRFVEMMJEHHUD4H     0.8866     Checkered Single Breasted Casual Women Blazer  (Purple)
# BZRFZQ9JQHGHEQSK     0.8688     Solid Single Breasted Casual Women Blazer  (Blue)
# SHTFW5YQKBZGM6QJ     0.8653     Men Regular Fit Washed Spread Collar Casual Shirt
# SHTFW5YQDBGGX4VR     0.8653     Men Regular Fit Washed Spread Collar Casual Shirt
# SHTFWAJBK3YSEQAR     0.8653     Men Regular Fit Washed Spread Collar Casual Shirt
# SHTFW5YQBHTHZYYF     0.8653     Men Regular Fit Washed Spread Collar Casual Shirt
# SHTFW5YQWN6NEUDM     0.8653     Men Regular Fit Washed Spread Collar Casual Shirt
#
# Word2Vec Results for: brand blend fabric shirt
# ================================================================================
# PID                  SCORE      TITLE
# --------------------------------------------------------------------------------
# FABFZH85MZ8S52FH     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8ZQAFJU7AW     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8HGKDW2MZK     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH7ZKYZEAH6T     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8Q9UJHHHGZ     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8SHA4ZPGNU     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZHGYFDTXRKMY     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8AGS4WTKPW     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH92SREJWEV2     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
# FABFZH8KCK8E2KH3     0.9624     Cotton Polyester Blend Printed Shirt Fabric  (Unstitched)
